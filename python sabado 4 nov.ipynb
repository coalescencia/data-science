# %%
def my_grep(file_name, patron):
    text=!cat $file_name
    repeticiones=text.spstr.upper().count(patron.upper())
    return repeticiones

# %%
my_grep("./historico_python.txt",'historico')
# Out:
# 3

# %%
b=!ls -l

# %%
b[:2]
# Out:
# ['total 336', '-rw-rw-r--   1 dsc dsc    58 Oct 27 19:52 20lines2.txt']

# %%
b.spstr[:50]
# Out:
# 'total 336 -rw-rw-r--   1 dsc dsc    58 Oct 27 19:5'

# %%
b.spstr[:50].upper().count('dsc'.upper())
# Out:
# 2

# %%
b.spstr[:50].upper().count('r'.upper())
# Out:
# 3

# %%
# !cat historico_python.txt
# Out:
#  1/1: sc
#  1/2: sc.version
#  1/3: r = sc.parallelize([1,2,3])
#  1/4: r.sum
#  1/5: r.sum()
#  2/1: l = ""
#  2/2: l.split()
#  3/1: sc
#  3/2: sc.textFile()
#  3/3: import pandas as pd
#  6/1: import readline
#  7/1: import os
#  8/1: sc
#  8/2: sc.version
# 11/1:
# # add all elements in the collection
# reduce(lambda x,y: x+y,a)
# 11/2:
# a = range(1,10)
# map(lambda x: x+1,a)
# 11/3:
# # add all elements in the collection
# reduce(lambda x,y: x+y,a)
# 11/4:
# # fin the maximum in the collection
# reduce(lambda x,y: x if x>y else y,a)
# 11/5:
# # subtract all elements in the collection: this is not commutative
# print reduce(lambda x,y: x-y,a)
# print reduce(lambda x,y: y-x,a)
# 11/6:
# # subtract all elements in the collection. We can give a default value to start with.
# print reduce(lambda x,y: x-y,[1,2,3])
# print reduce(lambda x,y: x-y,[1,2,3],0)
# print reduce(lambda x,y: x-y,[1,2,3],6)
# 11/7:
# # Create array of numbers with repeated elements
# import random
# ...

# %% [markdown]
# # LISTAS Y TUPLAS

# %%
a_lista=[2,3,None,7]

# %%
b_lista=a_lista+a_lista

# %%
b_lista
# Out:
# [2, 3, None, 7, 2, 3, None, 7]

# %%
c_lista=list([a_lista,a_lista])

# %%
c_lista
# Out:
# [[2, 3, None, 7], [2, 3, None, 7]]

# %%
c_lista[0]
# Out:
# [2, 3, None, 7]

# %%
c_lista[0][0]
# Out:
# 2

# %%
c_lista[0][1]
# Out:
# 3

# %%
d=['Yo','vivo','en']

# %%
d
# Out:
# ['Yo', 'vivo', 'en']

# %%
d.append('Madrid')

# %%
d
# Out:
# ['Yo', 'vivo', 'en', 'Madrid']

# %%
id(d)
# Out:
# 140555597981896

# %%
#al modificar d se convierte en otro objeto nuevo, lo vemos consultando su id
d=d+['desde','siempre']; id(d)
# Out:
# 140555597688136

# %%
d
# Out:
# ['Yo', 'vivo', 'en', 'Madrid', 'desde', 'siempre']

# %%
'vivo' in d
# Out:
# True

# %%
'hola' in d
# Out:
# False

# %%
d.remove('siempre')

# %%
d
# Out:
# ['Yo', 'vivo', 'en', 'Madrid', 'desde']

# %%
#devuelve el elemento y lo borra de la lista
elemento_2=d.pop(2);
elemento_2, d
# Out:
# ('Madrid', ['Yo', 'vivo', 'desde'])

# %%
elemento_2
# Out:
# 'Madrid'

# %%
numeros=[4,2,5,1,9]

# %%
numeros.sort()

# %%
numeros
# Out:
# [1, 2, 4, 5, 9]

# %%
print(sorted(numeros))
# Out:
# [1, 2, 4, 5, 9]

# %%
numeros
# Out:
# [1, 2, 4, 5, 9]

# %%
numeros
# Out:
# [1, 2, 4, 5, 9]

# %%
palabras=['Hola', 'fox', 'he','helll', 'man','small']

# %%
palabras.sort();palabras
# Out:
# ['Hola', 'fox', 'he', 'helll', 'man', 'small']

# %%
palabras.sort(key=str.lower); palabras
# Out:
# ['fox', 'he', 'helll', 'Hola', 'man', 'small']

# %%
palabras.sort(key=len, reverse=True); palabras
# Out:
# ['helll', 'small', 'Hola', 'fox', 'man', 'he']

# %%
palabras.sort(key=lambda x:x.count('l'));palabras
# Out:
# ['fox', 'man', 'he', 'Hola', 'small', 'helll']
